# %%
import os
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shapely
import supervision as sv
import sklearn
import torch
import torchvision
import torchvision.transforms as transforms
import PIL

# %% [markdown]
# # **Datasets**

# %% [markdown]
# ## **The dataset Dataset_for_YOLO was initially downloaded from the link provided by the mentor. Native Image chips and native labels were taken from the folder. The images were converted to the .jpeg format from .tif format and the duplicate copies were removed as a part of Data Cleaning.**
# ## **The Dataset_for_AP50 has 10 downloded images converted to 100 x 100 px dimensions and annotated using CVAT.ai to create a ground truth box and a prediction box each of 20 x 20 px size.**

# %% [markdown]
# # **Data Exploration and Understanding**

# %%
img_dir='/kaggle/input/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images'
label_dir='/kaggle/input/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels'

# %% [markdown]
# ## **1. Dataset statistics**

# %% [markdown]
# ### **a. How many instances of solar panels are present in the dataset**
#
# ### **b. Compute and show the value counts of labels per image. E.g., X images have 0 labels, Y images have 1 label, … and so on.**

# %%
total_count = 0
file_no=0
obj_inst_dict={}

# %%
for label_file in os.listdir(label_dir):
    file_path = os.path.join(label_dir, label_file)
    with open(file_path, 'r', encoding='latin-1') as file:
        obj_count=0
        for line in file:
            obj_count+=1
            total_count+=1;
        file_no+=1 

        if obj_count in obj_inst_dict:
            obj_inst_dict[obj_count]=obj_inst_dict[obj_count]+1
        else:
            obj_inst_dict[obj_count]=1

# %%
total_img=0
total_inst_count=0
df = pd.DataFrame(columns=['Instances per image','No. of such images'])
index=0

for key, values in obj_inst_dict.items():
    df.loc[index]=[key,values]
    index+=1
    total_img+=values
    total_inst_count+=(key*values)
    print(f'{values} images have {key} solar-panels per image.')
print(f'There are {total_count} solar panel instances in {total_img} images.')
    
df.loc[index]=[f'Total Instances:{total_inst_count}',f'Total Images:{total_img}' ]
# Out:
# 7 images have 32 solar-panels per image.
# 221 images have 3 solar-panels per image.
# 218 images have 4 solar-panels per image.
# 36 images have 17 solar-panels per image.
# 217 images have 5 solar-panels per image.
# 25 images have 18 solar-panels per image.
# 49 images have 14 solar-panels per image.
# 169 images have 9 solar-panels per image.
# 97 images have 11 solar-panels per image.
# 81 images have 1 solar-panels per image.
# 189 images have 6 solar-panels per image.
# 19 images have 34 solar-panels per image.
# 6 images have 36 solar-panels per image.
# 14 images have 20 solar-panels per image.
# 121 images have 10 solar-panels per image.
# 170 images have 7 solar-panels per image.
# 5 images have 74 solar-panels per image.
# 167 images have 2 solar-panels per image.
# 84 images have 12 solar-panels per image.
# 41 images have 16 solar-panels per image.
# 1 images have 75 solar-panels per image.
# 184 images have 8 solar-panels per image.
# 13 images have 38 solar-panels per image.
# 4 images have 66 solar-panels per image.
# 10 images have 41 solar-panels per image.
# 69 images have 13 solar-panels per image.
# 9 images have 40 solar-panels per image.
# 5 images have 49 solar-panels per image.
# 29 images have 19 solar-panels per image.
# 2 images have 60 solar-panels per image.
# 6 images have 39 solar-panels per image.
# 4 images have 21 solar-panels per image.
# 6 images have 54 solar-panels per image.
# 9 images have 51 solar-panels per image.
# 2 images have 76 solar-panels per image.
# 6 images have 62 solar-panels per image.
# 46 images have 15 solar-panels per image.
# 3 images have 65 solar-panels per image.
# 17 images have 37 solar-panels per image.
# 6 images have 50 solar-panels per image.
# 1 images have 64 solar-panels per image.
# 13 images have 33 solar-panels per image.
# 10 images have 35 solar-panels per image.
# 12 images have 42 solar-panels per image.
# 20 images have 30 solar-panels per image.
# 3 images have 48 solar-panels per image.
# 8 images have 31 solar-panels per image.
# 5 images have 28 solar-panels per image.
# 4 images have 53 solar-panels per image.
# 4 images have 44 solar-panels per image.
# 4 images have 23 solar-panels per image.
# 5 images have 27 solar-panels per image.
# 15 images have 29 solar-panels per image.
# 4 images have 25 solar-panels per image.
# 3 images have 63 solar-panels per image.
# 9 images have 47 solar-panels per image.
# 11 images have 43 solar-panels per image.
# 16 images have 52 solar-panels per image.
# 2 images have 24 solar-panels per image.
# 3 images have 58 solar-panels per image.
# 2 images have 77 solar-panels per image.
# 2 images have 45 solar-panels per image.
# 1 images have 61 solar-panels per image.
# 2 images have 59 solar-panels per image.
# 3 images have 26 solar-panels per image.
# 1 images have 55 solar-panels per image.
# 5 images have 46 solar-panels per image.
# 1 images have 71 solar-panels per image.
# 1 images have 56 solar-panels per image.
# 1 images have 72 solar-panels per image.
# 1 images have 78 solar-panels per image.
# 1 images have 73 solar-panels per image.
# 1 images have 67 solar-panels per image.
# 1 images have 22 solar-panels per image.
# There are 29625 solar panel instances in 2542 images.

# %%
print(df)
# Out:
#       Instances per image No. of such images
# 0                      32                  7
# 1                       3                221
# 2                       4                218
# 3                      17                 36
# 4                       5                217
# ..                    ...                ...
# 70                     78                  1
# 71                     73                  1
# 72                     67                  1
# 73                     22                  1
# 74  Total Instances:29625  Total Images:2542
#
# [75 rows x 2 columns]

# %%
labels_pth='/kaggle/input/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels'
class_0=[]
class_1=[]
class_2=[]

classes=[]
for label_file in os.listdir(labels_pth):
    with open(os.path.join(labels_pth,label_file), 'r') as file:
        class_id=0
        for line in file:
            class_id=line.split()[0]
            if class_id not in classes:
                classes.append(class_id)
        if class_id=='0':
            class_0.append(line)
        if class_id=='1':
                class_1.append(line)
        if class_id=='2':
            class_2.append(line)

print(f'The list of distinct classes: {classes}')
print(f'No. of Images with Class-0: {len(class_0)}')
print(f'No. of Images with Class-1: {len(class_1)}')
print(f'No. of Images with Class-2: {len(class_2)}')
# Out:
# The list of distinct classes: ['0', '2', '1']
# No. of Images with Class-0: 2468
# No. of Images with Class-1: 30
# No. of Images with Class-2: 44

# %% [markdown]
# ### **Answer:**
# ### **a. There are 29625 solar panel instances in 2542 images.**
# ### **b. Check previous code cells' outputs for imagewise instances**
#
# ### **The list of distinct classes: ['0', '2', '1']**
# ### **No. of Images with Class-0: 2468**
# ### **No. of Images with Class-1: 30**
# ### **No. of Images with Class-2: 44**

# %% [markdown]
# ## **2. Calculate the statistics of the area of solar panels in meters (Read label readme carefully for this question)**

# %% [markdown]
# ### **a. What method was used to compute the area (in meters) for a single instance?**
# ### **Answer:**
# ### **For a single instance(each line in a label(.txt) file represents an instance), its figures represent x_center, y_center, width and height respectively of the bounding box of that instance. Now, these coordinates are given in normalized form with respect to the pixel size of the image-chip taken. This image size is 416x416 according to the README file for Labels. Thus each coordinate is transformed back to its original pixel value by multiplying with 416. Also, these pixel values were actually scaled from metric units like meters. The scale factor can be obtained as 0.31 from coordinate system representation of each tile in the README file. Thus, further mutiplying the pixels by 0.31 results into metric values in meteres. Using the metric widths and heights of the bounding box, we get areas.**
# ### **width_in_m= width x 416 x 0.31**
# ### **height_in_m= height x 416 x 0.31**
# ### **Area= width_in_m x height_in_m**

# %% [markdown]
# ### **b. What is the mean area and standard deviation?**

# %%
def get_area(x_val, y_val, px_size, scale_factor):
    x_px=x_val*px_size
    y_px=y_val*px_size
    x_len=scale_factor*x_px
    y_len=scale_factor*y_px

    return (x_len*y_len)

# %%
area_list=np.array([])

# %%
for label_file in os.listdir(label_dir):
    file_path = os.path.join(label_dir, label_file)
    with open(file_path, 'r', encoding='latin-1') as file:
        for line in file:
            category, x_center, y_center, x_width, y_width = line.split()
            x_center=float(x_center)
            y_center=float(y_center)
            x_width=float(x_width)
            y_width=float(y_width)
            area_list=np.append(area_list,get_area(x_width, y_width, px_size=416, scale_factor=0.31))
print(area_list[:20])
# Out:
# [  9.61   136.462  622.728  622.5358 630.416   38.7283  76.1112 139.2489
#  219.8768 327.701  181.629  510.4832 186.8184 505.9665 533.1628 344.4224
#  415.152  299.832  401.8902 306.8473]

# %%
mean_area=np.sum(area_list)/len(area_list)
print(mean_area)
# Out:
# 191.51782786497895

# %%
std_dev_area=np.sqrt(np.sum(np.power((area_list-mean_area),2))/len(area_list))
print(std_dev_area)
# Out:
# 630.7003355500087

# %% [markdown]
# ### **Answer:**
# ### **The mean of all the areas is 191.51782786497895 sq. units and standard deviation is 630.7003355500087. sq. units**

# %% [markdown]
# ### **c. Plot the histogram of areas. What do you observe?**

# %%
fig, ax = plt.subplots()
ax.hist(area_list, bins=30, log=True, linewidth=0.5,edgecolor='black')
ax.set(xlim=(0, 13000))
plt.xlabel(f'\nAreas of solar panels (sq. m)')
plt.ylabel(f'\nNo. of instances')
plt.show()

# %% [markdown]
# ### **Answer:**
# ### **Above is the histogram of all the areas. We observe that no. of solar panels with areas <2000 sq. m is higher as it is convenient for many households and small commercial centres. On the other hand, the solar panels with higher areas like >6000 sq. m is relatively very less. This might be the represetation of industrial units which use solar power. Their no. is evidently very less compared to residential units.**

# %% [markdown]
# # **Implementing the Fundamental Functions**

# %% [markdown]
# ## **1. Write a function to compute IoU (Intersection over Union) https://pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/ between two axis-aligned bounding boxes specified in the Ultralytics YOLO format. You MUST use the shapely library [https://pypi.org/project/shapely/] and its functionalities to write your function. Show that your function provides the same or similar answer as IoU computed using `supervision` library.**

# %%
def get_coords(label, px_size=1, scale_factor=1):
    class_id, x_center, y_center, width, height=label
    x_val=(x_center*px_size)*scale_factor
    y_val=(y_center*px_size)*scale_factor
    width=(width*px_size)*scale_factor
    height=(height*px_size)*scale_factor
    x_min=x_val-(width/2)
    x_max=x_val+(width/2)
    y_min=y_val-(height/2)
    y_max=y_val+(height/2)

    return x_min, y_min, x_max, y_max

# %%
from shapely.geometry import Polygon

# %%
def get_shapely_iou(gt_bbox_coords, pred_bbox_coords):
    x_min_gt, y_min_gt, x_max_gt, y_max_gt=gt_bbox_coords
    x_min_pred, y_min_pred, x_max_pred, y_max_pred=pred_bbox_coords
    gt_polygon=Polygon([(x_min_gt,y_min_gt),(x_max_gt, y_min_gt),(x_max_gt, y_max_gt),(x_min_gt, y_max_gt)])
    pred_polygon=Polygon([(x_min_pred,y_min_pred),(x_max_pred, y_min_pred),(x_max_pred, y_max_pred),(x_min_pred, y_max_pred)])
    area_of_intersection=gt_polygon.intersection(pred_polygon).area
    area_of_union=gt_polygon.union(pred_polygon).area
    iou_shapely=area_of_intersection/area_of_union
    return iou_shapely

# %%
def get_supervision_iou(gt_bbox_coords, pred_bbox_coords):
    x_min_gt, y_min_gt, x_max_gt, y_max_gt=gt_bbox_coords
    x_min_pred, y_min_pred, x_max_pred, y_max_pred=pred_bbox_coords
    gt_coords=np.array([x_min_gt, y_min_gt, x_max_gt, y_max_gt]).reshape(1,-1)
    pred_coords=np.array([x_min_pred, y_min_pred, x_max_pred, y_max_pred]).reshape(1,-1)
    iou_sv=sv.box_iou_batch(gt_coords, pred_coords).item()
    return iou_sv

# %%
label_gt = (0, 0.5, 0.5, 0.2, 0.2)   
label_pred = (0, 0.6, 0.5, 0.2, 0.2)  

gt_bbox_coords= get_coords(label_gt, px_size=416, scale_factor=0.31)
pred_bbox_coords= get_coords(label_pred, px_size=416, scale_factor=0.31)

print(f"IoU from supervision library: {get_supervision_iou(gt_bbox_coords, pred_bbox_coords)}")
print(f"IoU from shapely library: {get_shapely_iou(gt_bbox_coords, pred_bbox_coords)}")
# Out:
# IoU from supervision library: 0.3333333333333333
# IoU from shapely library: 0.3333333333333333

# %% [markdown]
# ### **Answer: Both the methods give us IoU of around 0.333.**

# %% [markdown]
# ## **2. Write a function to compute Average Precision (AP):**
# ### **a. Use Pascal VOC 11 point interpolation method to implement the function.**
# ### **b. Use COCO 101-point interpolation method to implement the function.**
# ### **c. Use Area under Precision-Recall Curve (AP) method to implement the function.**
# ### **d. Randomly generate 10 images of size 100x100. Randomly generate 10 ground truth boxes of size 20x20 and 10 predicted boxes of size 20x20 in each image. Assume there is only one class of objects. Compare the AP50 (Average Precision at IoU 0.5) computed by 3 of your methods**

# %% [markdown]
# ### **Answer:**

# %% [markdown]
# ### **Path to randomly taken and processed images (to 100 x 100 px size) along with YOLO-annotations generated using CVAT.ai:**

# %%
img_pth_ap50='/kaggle/input/datasets-for-object-detection-task/Datasets/Dataset_for_AP50/images_for_AP50'
labels_pth_ap50='/kaggle/input/datasets-for-object-detection-task/Datasets/Dataset_for_AP50/labels_for_AP50'

# %% [markdown]
# ### **Function to generate Ground Truths and Predictions:**

# %%
def get_gts_preds(img_pth, label_pth):
    gt_list=[]
    pred_list=[]
    np.random.seed(42)
    n=len(os.listdir(label_pth))
    confidence_scores=np.random.uniform(0,1,n)
    index=0
    for label_file in os.listdir(label_pth):
        file_path = os.path.join(label_pth, label_file)
        lines=[]
        with open(file_path, 'r', encoding='latin-1') as file:
            for line in file:
                lines.append(line)
                
            gt_class, gt_x_cen, gt_y_cen, gt_width, gt_height=lines[0].split()
            gt={}
            gt['image_id']=index+1
            gt['class_id']=int(gt_class)
            gt['bbox']=get_coords((gt_class, float(gt_x_cen), float(gt_y_cen), float(gt_width), float(gt_height)))
            gt_list.append(gt)

            pred_class, pred_x_cen, pred_y_cen, pred_width, pred_height=lines[1].split()
            pred={}
            pred['class_id']=int(pred_class)
            pred['bbox']=get_coords((pred_class, float(pred_x_cen), float(pred_y_cen), float(pred_width), float(pred_height)))
            pred['confidence']=confidence_scores[index]
            pred_list.append(pred)
            
        index+=1
    return gt_list, pred_list

# %%
gts, preds=get_gts_preds(img_pth_ap50, labels_pth_ap50)

# %% [markdown]
# ### **Function to calculate AP50 by PASCAL VOC 11-point interpolation method:**

# %%
def ap50_by_pascal_voc_11(gts,preds):
    tp=0
    fp=0
    prec_recall_pairs=[]
    matched_gts=[]
    preds_sorted=sorted(preds, key=lambda x: x['confidence'], reverse=True)
    for pred in preds_sorted:
        precision=0
        recall=0
        iou_list=[]
        for gt in gts:
            iou_list.append(get_shapely_iou(gt['bbox'],pred['bbox']))
        max_iou=np.max(iou_list)
        matching_gt_idx=np.argmax(iou_list)
        matching_gt=gts[matching_gt_idx]
        if matching_gt not in matched_gts:
            matched_gts.append(matching_gt)
            if(max_iou>=0.5):
                tp+=1
            else:
                fp+=1
        else:
            fp+=1
        precision=tp/(tp+fp)
        recall=tp/len(gts)
        prec_recall_pairs.append((precision,recall))

    recall_thresholds=np.linspace(0,1,11)
    interpolated_precs=[]
    for recall_th in recall_thresholds:
        interpolated_prec=0
        for prec,rec in prec_recall_pairs:
            if rec>=recall_th:
                interpolated_prec=max(interpolated_prec,prec)
        interpolated_precs.append(interpolated_prec)
    avg_prec=np.mean(interpolated_precs)
    return avg_prec

# %% [markdown]
# ### **Function to calculate AP50 by COCO 101-point interpolation method:**

# %%
def ap50_by_coco_101(gts,preds):
    tp=0
    fp=0
    prec_recall_pairs=[]
    matched_gts=[]
    preds_sorted=sorted(preds, key=lambda x: x['confidence'], reverse=True)
    for pred in preds_sorted:
        precision=0
        recall=0
        iou_list=[]
        for gt in gts:
            iou_list.append(get_shapely_iou(gt['bbox'],pred['bbox']))
        max_iou=np.max(iou_list)
        matching_gt_idx=np.argmax(iou_list)
        matching_gt=gts[matching_gt_idx]
        if matching_gt not in matched_gts:
            matched_gts.append(matching_gt)
            if(max_iou>=0.5):
                tp+=1
            else:
                fp+=1
        else:
            fp+=1
        precision=tp/(tp+fp)
        recall=tp/len(gts)
        prec_recall_pairs.append((precision,recall))

    recall_thresholds=np.linspace(0,1,101)
    interpolated_precs=[]
    for recall_th in recall_thresholds:
        interpolated_prec=0
        for prec,rec in prec_recall_pairs:
            if rec>=recall_th:
                interpolated_prec=max(interpolated_prec,prec)
        interpolated_precs.append(interpolated_prec)
    avg_prec=np.mean(interpolated_precs)
    return avg_prec

# %% [markdown]
# ### **Function to calculate AP50 by AUC-PR curve method:**

# %%
from sklearn.metrics import precision_recall_curve, auc

# %%
def ap50_by_auc_pr(gts,preds):
    y_true=[]
    y_pred_confid_scrs=[]
    matched_gts=[]
    for pred in preds:
        iou_list=[]
        for gt in gts:
            iou_list.append(get_shapely_iou(gt['bbox'],pred['bbox']))
        max_iou=np.max(iou_list)
        matching_gt_idx=np.argmax(iou_list)
        matching_gt=gts[matching_gt_idx]
        if matching_gt not in matched_gts:
            matched_gts.append(matching_gt)
            if(max_iou>=0.5):
                y_true.append(1)
            else:
                y_true.append(0)
        else:
            y_true.append(0)
        y_pred_confid_scrs.append(pred['confidence'])
    precision, recall, _ = precision_recall_curve(y_true, y_pred_confid_scrs)
    ap50 = auc(recall, precision)
    return ap50

# %% [markdown]
# ### **AP50 by all 3 methods:**

# %%
ap50_by_pascal_voc_11(gts,preds)
# Out:
# 0.22727272727272727

# %%
ap50_by_coco_101(gts,preds)
# Out:
# 0.1914191419141914

# %%
ap50_by_auc_pr(gts,preds)
# Out:
# 0.5694444444444444

# %% [markdown]
# ### **The AP50 calculated is: 0.22727272727272727 by PASCAL VOC 11 point interpolation method, 0.1914191419141914 by COCO 101 point interpolation and 0.5694444444444444 by Area-Under-PR-Curve method. COCO 101 gives less AP50 that PASCAL VOC because it checks precision variation at 101 points as compared to only 11 points in PASCAL VOC, and thus taking into account more no. of variations in precisions. AUC-PR method gives best value as it integrates the entire P-R curve considering all precision values across all recall values.**

# %% [markdown]
# # **Model building and evaluation**

# %% [markdown]
# ## **Split the data into 80-20 train-test split. Use 10% of training data as validation.**

# %% [markdown]
# #### **Copying the dataset to working directory for train-test split.**

# %%
![ -d /kaggle/working/datasets-for-object-detection-task ] || cp -r /kaggle/input/datasets-for-object-detection-task /kaggle/working/

# %% [markdown]
# ### **Function to create train-test split:**

# %%
def create_train_test_val_dirs(img_dir, label_dir, train_fraction, val_fraction):
    images=os.listdir(img_dir)
    np.random.seed(42)
    np.random.shuffle(images)
    train_len=int(train_fraction*len(images))
    train_imgs=images[:train_len] 
    test_imgs=images[train_len:]
    val_len=int(val_fraction*len(train_imgs))
    val_imgs=train_imgs[:val_len]  
    train_imgs=train_imgs[val_len:]

    labels=os.listdir(label_dir)
    train_labels=[]
    test_labels=[]
    val_labels=[]
    
    for label_name in labels:
        corresp_img=label_name.replace(".txt",".jpeg")
        if corresp_img in train_imgs:
            train_labels.append(label_name)
        elif corresp_img in test_imgs:
            test_labels.append(label_name)
        else:
            val_labels.append(label_name)

    train_imgs=np.sort(train_imgs)
    train_labels=np.sort(train_labels)
    test_imgs=np.sort(test_imgs)
    test_labels=np.sort(test_labels)
    val_imgs=np.sort(val_imgs)
    val_labels=np.sort(val_labels)
    
    train_img_dir=os.path.join(img_dir,'train')
    train_label_dir=os.path.join(label_dir,'train')
    test_img_dir=os.path.join(img_dir,'test')
    test_label_dir=os.path.join(label_dir,'test')
    val_img_dir=os.path.join(img_dir,'val')
    val_label_dir=os.path.join(label_dir,'val')

    folder_pths=[train_img_dir, train_label_dir, test_img_dir, test_label_dir, val_img_dir, val_label_dir]
    
    for folder_pth in folder_pths:
        os.makedirs(folder_pth, exist_ok=True)

    files_and_pths_list=[(train_imgs,img_dir,train_img_dir),(train_labels,label_dir,train_label_dir),(test_imgs,img_dir,test_img_dir),(test_labels,label_dir,test_label_dir),(val_imgs,img_dir,val_img_dir),(val_labels,label_dir,val_label_dir)]
    
    for files_list, src_fldr, dest_fldr in files_and_pths_list:
        for file in files_list:
            if os.path.exists(os.path.join(src_fldr, file)) and not os.path.exists(os.path.join(dest_fldr, file)):
                shutil.move(os.path.join(src_fldr, file), os.path.join(dest_fldr, file))

# %%
img_dir_pth='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images'
label_dir_pth='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels'

# %%
create_train_test_val_dirs(img_dir_pth, label_dir_pth, 0.8, 0.1)

# %% [markdown]
# ## **1. Use any model from Ultralytics like YOLO to train the object detection model. Show that validation loss is converged.**

# %% [markdown]
# ### **Model Training using YOLOv8n**

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# #### **Creating data.yaml file.**

# %%
config_file_content = """path: /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO
train: /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/train
val: /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/val
test: /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test

nc: 3
names: ["solar_panel_type1","solar_panel_type2","solar_panel_type3"]
"""
config_file_pth = "/kaggle/working/data.yaml"
if not os.path.exists(config_file_pth):
    with open(config_file_pth, "w") as file:
        file.write(config_file_content)

    print(f"data.yaml created at {config_file_pth}")
# Out:
# data.yaml created at /kaggle/working/data.yaml

# %% [markdown]
# #### **Training the model for 70 epochs:**

# %%
model=YOLO("yolov8n.pt")
model.train(data="/kaggle/working/data.yaml", epochs=70)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 114MB/s]
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/kaggle/working/data.yaml, epochs=70, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 25.2MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 124MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels/train... 1830 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1830/1830 [00:01<00:00, 1084.39it/s]
# train: New cache created: /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# UserWarning: A new version of Albumentations is available: 2.0.4 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# val: Scanning /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels/val... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<00:00, 921.09it/s]
# val: New cache created: /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 70 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/70      2.93G      1.668      2.148      1.351         59        640: 100%|██████████| 115/115 [00:20<00:00,  5.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<00:00,  2.48it/s]
#                    all        203       2496      0.913      0.168      0.204      0.119
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/70      3.66G      1.393      1.241      1.171        109        640: 100%|██████████| 115/115 [00:18<00:00,  6.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  4.60it/s]
#                    all        203       2496      0.938      0.233      0.259      0.157
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/70      2.67G      1.337       1.12      1.151         73        640: 100%|██████████| 115/115 [00:18<00:00,  6.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  4.62it/s]
#                    all        203       2496      0.951      0.266       0.31        0.2
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/70      2.95G      1.293      1.001      1.124        108        640: 100%|██████████| 115/115 [00:18<00:00,  6.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x78a37f61f130>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
# ...
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.33746,     0.33746,     0.42988, ...,           1,           1,           1],
#        [   0.043988,    0.043988,    0.062976, ...,           1,           1,           1],
#        [   0.040404,    0.040404,    0.065561, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.98539,     0.98539,     0.98295, ...,           0,           0,           0],
#        [          1,           1,     0.93645, ...,           0,           0,           0],
#        [    0.94118,     0.94118,     0.94118, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: 0.7397955266882572
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.83579,     0.57902,     0.75785])
# names: {0: 'solar_panel_type1', 1: 'solar_panel_type2', 2: 'solar_panel_type3'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.9885817865652561, 'metrics/recall(B)': 0.8257782084987967, 'metrics/mAP50(B)': 0.8799771187151261, 'metrics/mAP50-95(B)': 0.7242197942408273, 'fitness': 0.7397955266882572}
# save_dir: PosixPath('runs/detect/train')
# speed: {'preprocess': 0.20058379311369315, 'inference': 2.034818492606503, 'loss': 0.0006247536981982418, 'postprocess': 9.059302738919744}
# task: 'detect'

# %% [markdown]
# #### **Plotting Validation Losses against epochs: Shows Convergence**

# %%
results_path="/kaggle/working/runs/detect/train/results.csv"  
results=pd.read_csv(results_path)

plt.figure(figsize=(8, 5))
plt.plot(results["epoch"], results["val/box_loss"], label="Val Box Loss")
plt.plot(results["epoch"], results["val/cls_loss"], label="Val Classification Loss")
plt.plot(results["epoch"], results["val/dfl_loss"], label="Val Distribution Focal Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Validation Losses")
plt.show()

# %% [markdown]
# #### **Making Predictions:**

# %%
model=YOLO("runs/detect/train/weights/best.pt")  
pred_results=model.predict("/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test", save=True)
# Out:
# image 1/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_0_y0_7229_dxdy_416.jpeg: 640x640 15 solar_panel_type1s, 1 solar_panel_type3, 7.4ms
# image 2/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_0_y0_7303_dxdy_416.jpeg: 640x640 10 solar_panel_type1s, 7.4ms
# image 3/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_0_y0_7418_dxdy_416.jpeg: 640x640 7 solar_panel_type1s, 7.4ms
# image 4/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1001_y0_7022_dxdy_416.jpeg: 640x640 4 solar_panel_type1s, 7.3ms
# image 5/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_10044_y0_10824_dxdy_416.jpeg: 640x640 8 solar_panel_type1s, 7.3ms
# image 6/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1016_y0_6504_dxdy_416.jpeg: 640x640 8 solar_panel_type1s, 7.3ms
# image 7/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_10336_y0_10994_dxdy_416.jpeg: 640x640 4 solar_panel_type1s, 7.3ms
# image 8/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1052_y0_7606_dxdy_416.jpeg: 640x640 16 solar_panel_type1s, 7.3ms
# image 9/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1073_y0_8078_dxdy_416.jpeg: 640x640 9 solar_panel_type1s, 7.3ms
# image 10/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1075_y0_8779_dxdy_416.jpeg: 640x640 12 solar_panel_type1s, 7.3ms
# image 11/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1081_y0_8886_dxdy_416.jpeg: 640x640 10 solar_panel_type1s, 7.3ms
# image 12/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1087_y0_6107_dxdy_416.jpeg: 640x640 8 solar_panel_type1s, 7.4ms
# image 13/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0_1099_y0_7866_dxdy_416.jpeg: 640x640 10 solar_panel_type1s, 7.3ms
# image 14/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_1__x0
509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_9525_y0_10829_dxdy_416.jpeg: 640x640 7 solar_panel_type1s, 5.8ms
# image 504/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_9609_y0_10688_dxdy_416.jpeg: 640x640 8 solar_panel_type1s, 6.0ms
# image 505/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_9637_y0_14691_dxdy_416.jpeg: 640x640 17 solar_panel_type1s, 5.7ms
# image 506/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_9687_y0_14891_dxdy_416.jpeg: 640x640 11 solar_panel_type1s, 5.7ms
# image 507/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_9760_y0_13018_dxdy_416.jpeg: 640x640 3 solar_panel_type1s, 5.7ms
# image 508/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_9771_y0_14144_dxdy_416.jpeg: 640x640 5 solar_panel_type1s, 5.8ms
# image 509/509 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_9889_y0_9987_dxdy_416.jpeg: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# ## **2. Predict solar panels using the trained model. Visualize the ground truth and predicted bounding boxes on 3-4 random samples from the test dataset. Use appropriate color schemes to differentiate between ground truth and predicted labels.**
# **

# %%
def highlight_patch(image, x_min, y_min, x_max, y_max, color, thickness=2):
    copy_img = np.array(image)
    copy_img[y_min:y_min+thickness, x_min:x_max]=color  
    copy_img[y_max-thickness:y_max, x_min:x_max]=color  
    copy_img[y_min:y_max, x_min:x_min+thickness]=color  
    copy_img[y_min:y_max, x_max-thickness:x_max]=color  

    copy_img_tensor=torch.from_numpy(copy_img)

    return copy_img_tensor

# %%
from PIL import Image

# %%
test_img_dir='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test'
test_label_dir='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels/test'

np.random.seed(42)
test_samples=np.random.choice(os.listdir(test_img_dir),4)

for sample_img in test_samples:
    test_img_file=os.path.join(test_img_dir,sample_img)
    test_image = Image.open(test_img_file).convert("RGB")
    test_label_file=os.path.join(test_label_dir,sample_img.replace('.jpeg','.txt'))
    lines=[]
    with open(test_label_file, 'r', encoding='latin-1') as file:
        for line in file:
            lines.append(line)
        for line in lines:
            class_id, x_cen, y_cen, width, height=line.split()
            x_min, y_min, x_max, y_max=get_coords((class_id, float(x_cen), float(y_cen), float(width), float(height)),px_size=416)
            test_image=highlight_patch(test_image, int(x_min), int(y_min), int(x_max), int(y_max), color=np.array([255, 0, 0]))

    results=model(test_img_file)
    for result in results:
        for bbox in result.boxes.xyxy:
            x_min_pred=bbox[0]
            y_min_pred=bbox[1]
            x_max_pred=bbox[2]
            y_max_pred=bbox[3]
            test_image=highlight_patch(test_image, int(x_min_pred), int(y_min_pred), int(x_max_pred), int(y_max_pred), color=np.array([0, 255, 0]))
    
    plt.imshow(test_image.numpy())
    plt.title(f'{sample_img} Green: Prediction, Red: GT')
    plt.axis("off")
    plt.show()
# Out:
# image 1/1 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_4775_y0_13883_dxdy_416.jpeg: 640x640 7 solar_panel_type1s, 7.3ms
# Speed: 3.4ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_2__x0_5588_y0_6163_dxdy_416.jpeg: 640x640 5 solar_panel_type1s, 1 solar_panel_type2, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_8209_y0_12763_dxdy_416.jpeg: 640x640 8 solar_panel_type1s, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test/solarpanels_native_3__x0_6077_y0_8945_dxdy_416.jpeg: 640x640 4 solar_panel_type1s, 9.2ms
# Speed: 3.6ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ## **Use supervision.metrics functionality from supervision library to compute the following metrics.**
# ### **a. Compute mAP50 with supervision and compare with your implementation. What do you observe?**
# ###
# #### Documentation Reference used: https://supervision.roboflow.com/metrics/detection/#supervision.metrics.detection.MeanAveragePrecision.benchmark

# %%
from supervision.metrics import MeanAveragePrecision

# %%
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

dataset=sv.DetectionDataset.from_yolo(
    images_directory_path='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test',
    annotations_directory_path='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels/test',
    data_yaml_path='/kaggle/working/data.yaml'
)

def callback(image: np.ndarray) -> sv.Detections:
    result = model(image)[0]  
    return sv.Detections.from_ultralytics(result) 

mean_average_precision = sv.MeanAveragePrecision.benchmark(
    dataset=dataset, 
    callback=callback  
)

print(f"mAP@0.5: {mean_average_precision.map50}")
# Out:
# 0: 640x640 10 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 1 solar_panel_type2, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 43 solar_panel_type1s, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 solar_panel_type1s, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 43 solar_panel_type1s, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 31 solar_panel_type1s, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type3, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 1 solar_panel_type3, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 74 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 65 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.9ms
# Speed: 2.0ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 35 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 2 solar_panel_type2s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 32 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 49 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 39 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 2 solar_panel_type2s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 3 solar_panel_type2s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 2 solar_panel_type3s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.7ms
# Speed: 2.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 35 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 57 solar_panel_type1s, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 56 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 24 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 26 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 23 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 3 solar_panel_type2s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 3 solar_panel_type2s, 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 34 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 76 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type3, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 51 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 3 solar_panel_type2s, 5.7ms
# Speed: 2.5ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 2 solar_panel_type2s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 35 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 39 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type2, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 58 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 2 solar_panel_type2s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type2, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.3ms
# Speed: 2.4ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type2, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 32 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 51 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 1 solar_panel_type2, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.3ms
# Speed: 2.5ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.0ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 31 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 56 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 38 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.9ms
# Speed: 2.6ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 19 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type3, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.0ms
# ...
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 21 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type3, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 2.4ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 61 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 63 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type3s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type3, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 34 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 36 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 19 solar_panel_type1s, 1 solar_panel_type3, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 66 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 39 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 41 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 40 solar_panel_type1s, 5.7ms
# Speed: 2.5ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 2 solar_panel_type2s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 39 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.9ms
# Speed: 2.6ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 4 solar_panel_type2s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 2 solar_panel_type3s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type3s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 32 solar_panel_type1s, 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 29 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 1 solar_panel_type2, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type3s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 51 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# mAP@0.5: 0.9333214828505492

# %% [markdown]
# ### **Answer: The mAP@0.5 is 0.933.**

# %% [markdown]
# ### **Create a table of Precision, Recall and F1-scores where rows are IoU thresholds [0.1, 0.3, 0.5, 0.7, 0.9] and columns are confidence thresholds [0.1, 0.3, 0.5, 0.7, 0.9] (Hint use supervision.metrics.ConfusionMatrix to get the confusion matrix and get TP, FP and FN from it to compute the P, R and F-1)**
#
# ###
# #### Documentation Reference used: https://supervision.roboflow.com/metrics/detection/#supervision.metrics.detection.ConfusionMatrix.benchmark

# %%
iou_thresholds = [0.1, 0.3, 0.5, 0.7, 0.9]
conf_thresholds = [0.1, 0.3, 0.5, 0.7, 0.9]

model=YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

dataset=sv.DetectionDataset.from_yolo(
    images_directory_path='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/images/test',
    annotations_directory_path='/kaggle/working/datasets-for-object-detection-task/Datasets/Dataset_for_YOLO/labels/test',
    data_yaml_path='/kaggle/working/data.yaml'
)

def callback(image: np.ndarray) -> sv.Detections:
    result=model(image)[0]  
    return sv.Detections.from_ultralytics(result)

index_labels=[f"iou={iou}" for iou in iou_thresholds]
column_labels=[f"conf={conf}" for conf in conf_thresholds]
df=pd.DataFrame(index=index_labels, columns=column_labels)

for i, iou_thresh in enumerate(iou_thresholds):
    for j, conf_thresh in enumerate(conf_thresholds):
        confusion_matrix = sv.ConfusionMatrix.benchmark(
            dataset=dataset,
            callback=callback,
            iou_threshold=iou_thresh,
            conf_threshold=conf_thresh
            )

        conf_matrix=confusion_matrix.matrix
        num_classes=len(conf_matrix)-1  
        TP=np.diag(conf_matrix)[:num_classes] 
        FP=conf_matrix[-1, :num_classes] 
        FN=conf_matrix[:num_classes, -1] 

        micro_TP=np.sum(TP)
        micro_FP=np.sum(FP)
        micro_FN=np.sum(FN)
        
        micro_precision=micro_TP/(micro_TP+micro_FP)
        micro_recall=micro_TP/(micro_TP+micro_FN)
        micro_f1=2*(micro_precision*micro_recall)/(micro_precision+micro_recall)


        cell_value=f'P:{micro_precision:.3f} R:{micro_recall:.3f} F1:{micro_f1:.3f}'
        df.iloc[i, j]=cell_value
# Out:
# 0: 640x640 10 solar_panel_type1s, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 1 solar_panel_type2, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 43 solar_panel_type1s, 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 solar_panel_type1s, 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 43 solar_panel_type1s, 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 31 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type3, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 1 solar_panel_type3, 7.4ms
# Speed: 2.2ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 74 solar_panel_type1s, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 65 solar_panel_type1s, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 35 solar_panel_type1s, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 2 solar_panel_type2s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 5.8ms
# Speed: 2.6ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.5ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 32 solar_panel_type1s, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 solar_panel_type1s, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 49 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 39 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.0ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 2 solar_panel_type2s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 3 solar_panel_type2s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 2 solar_panel_type3s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 35 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 1 solar_panel_type3, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 57 solar_panel_type1s, 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 56 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 24 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 26 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 1 solar_panel_type3, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 23 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 3 solar_panel_type2s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 3 solar_panel_type2s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 34 solar_panel_type1s, 6.4ms
# Speed: 2.6ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 76 solar_panel_type1s, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type3, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 51 solar_panel_type1s, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 solar_panel_type1s, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 3 solar_panel_type2s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 2 solar_panel_type2s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 35 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 39 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type2, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 58 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 2 solar_panel_type2s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type2, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 1 solar_panel_type3, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type2, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 32 solar_panel_type1s, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 1 solar_panel_type3, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 51 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 1 solar_panel_type3, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 1 solar_panel_type2, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 1 solar_panel_type3, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 31 solar_panel_type1s, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 56 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 38 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 19 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 solar_panel_type1s, 5.8ms
# Speed: 2.5ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type3, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# ...
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 31 solar_panel_type1s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.6ms
# Speed: 2.1ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 56 solar_panel_type1s, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 38 solar_panel_type1s, 7.8ms
# Speed: 2.7ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 1 solar_panel_type3, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 30 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 19 solar_panel_type1s, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 20 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type3, 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 9.4ms
# Speed: 3.1ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 59 solar_panel_type1s, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 22 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 1 solar_panel_type3, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 15 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 2 solar_panel_type2s, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.7ms
# Speed: 2.8ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 9.5ms
# Speed: 2.9ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 8.4ms
# Speed: 2.8ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 7.8ms
# Speed: 2.3ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 8.2ms
# Speed: 2.9ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 18 solar_panel_type1s, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 72 solar_panel_type1s, 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 7.8ms
# Speed: 2.9ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.8ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 16 solar_panel_type1s, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.8ms
# Speed: 2.6ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 5.8ms
# Speed: 2.4ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 21 solar_panel_type1s, 6.8ms
# Speed: 2.3ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 1 solar_panel_type3, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 solar_panel_type1s, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 solar_panel_type1s, 6.3ms
# Speed: 2.4ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type1s, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 61 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 63 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 10 solar_panel_type3s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 42 solar_panel_type1s, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 14 solar_panel_type1s, 1 solar_panel_type3, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 34 solar_panel_type1s, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 1 solar_panel_type3, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 solar_panel_type1s, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 11 solar_panel_type1s, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 solar_panel_type1s, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 36 solar_panel_type1s, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 12 solar_panel_type1s, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 17 solar_panel_type1s, 1 solar_panel_type3, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 solar_panel_type1, 8.0ms
# Speed: 2.9ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 13 solar_panel_type1s, 1 solar_panel_type3, 8.2ms
# Speed: 2.9ms preprocess, 8.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 solar_panel_type1s, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 9 solar_panel_type1s, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 19 solar_panel_type1s, 1 solar_panel_type3, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
df
# Out:
#                          conf=0.1                  conf=0.3  \
# iou=0.1  P:0.935 R:0.972 F1:0.953  P:0.944 R:0.970 F1:0.957
# iou=0.3  P:0.935 R:0.971 F1:0.953  P:0.943 R:0.970 F1:0.956
# iou=0.5  P:0.933 R:0.970 F1:0.951  P:0.942 R:0.968 F1:0.955
# iou=0.7  P:0.918 R:0.953 F1:0.935  P:0.926 R:0.952 F1:0.939
# iou=0.9  P:0.658 R:0.683 F1:0.670  P:0.665 R:0.683 F1:0.674
#
#                          conf=0.5                  conf=0.7  \
# iou=0.1  P:0.978 R:0.956 F1:0.967  P:0.995 R:0.911 F1:0.951
# iou=0.3  P:0.978 R:0.956 F1:0.967  P:0.995 R:0.911 F1:0.951
# iou=0.5  P:0.978 R:0.956 F1:0.967  P:0.995 R:0.911 F1:0.951
# iou=0.7  P:0.963 R:0.942 F1:0.953  P:0.986 R:0.902 F1:0.942
# iou=0.9  P:0.697 R:0.681 F1:0.689  P:0.736 R:0.673 F1:0.703
#
#                          conf=0.9
# iou=0.1  P:1.000 R:0.388 F1:0.559
# iou=0.3  P:1.000 R:0.388 F1:0.559
# iou=0.5  P:1.000 R:0.388 F1:0.559
# iou=0.7  P:0.999 R:0.388 F1:0.559
# iou=0.9  P:0.943 R:0.366 F1:0.527

# %%
print(df)
# Out:
#                          conf=0.1                  conf=0.3  \
# iou=0.1  P:0.935 R:0.972 F1:0.953  P:0.944 R:0.970 F1:0.957
# iou=0.3  P:0.935 R:0.971 F1:0.953  P:0.943 R:0.970 F1:0.956
# iou=0.5  P:0.933 R:0.970 F1:0.951  P:0.942 R:0.968 F1:0.955
# iou=0.7  P:0.918 R:0.953 F1:0.935  P:0.926 R:0.952 F1:0.939
# iou=0.9  P:0.658 R:0.683 F1:0.670  P:0.665 R:0.683 F1:0.674
#
#                          conf=0.5                  conf=0.7  \
# iou=0.1  P:0.978 R:0.956 F1:0.967  P:0.995 R:0.911 F1:0.951
# iou=0.3  P:0.978 R:0.956 F1:0.967  P:0.995 R:0.911 F1:0.951
# iou=0.5  P:0.978 R:0.956 F1:0.967  P:0.995 R:0.911 F1:0.951
# iou=0.7  P:0.963 R:0.942 F1:0.953  P:0.986 R:0.902 F1:0.942
# iou=0.9  P:0.697 R:0.681 F1:0.689  P:0.736 R:0.673 F1:0.703
#
#                          conf=0.9
# iou=0.1  P:1.000 R:0.388 F1:0.559
# iou=0.3  P:1.000 R:0.388 F1:0.559
# iou=0.5  P:1.000 R:0.388 F1:0.559
# iou=0.7  P:0.999 R:0.388 F1:0.559
# iou=0.9  P:0.943 R:0.366 F1:0.527
